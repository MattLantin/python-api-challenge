# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
coordinate_pairs = []

# Empty list for holding the cities names
unique_cities = []

# Range of latitudes and longitudes
latitude_range = (-90, 90)
longitude_range = (-180, 180)

# Create a set of random lat and lng combinations
random_latitudes = np.random.uniform(latitude_range[0], latitude_range[1], size=1500)
random_longitudes = np.random.uniform(longitude_range[0], longitude_range[1], size=1500)
coordinate_pairs = zip(random_latitudes, random_longitudes)

# Identify nearest city for each lat, lng combination
for coords in coordinate_pairs:
    nearest_city = citipy.nearest_city(coords[0], coords[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if nearest_city not in unique_cities:
        unique_cities.append(nearest_city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(unique_cities)}")
# Out:
# Number of cities in the list: 588

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(unique_cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city.replace(' ', '+')}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ilulissat
# Processing Record 2 of Set 1 | sabang
# Processing Record 3 of Set 1 | bandon
# Processing Record 4 of Set 1 | port-aux-francais
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | kavaratti
# Processing Record 7 of Set 1 | broken hill
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | waitangi
# Processing Record 10 of Set 1 | tazovsky
# Processing Record 11 of Set 1 | katsuren-haebaru
# Processing Record 12 of Set 1 | hawaiian paradise park
# Processing Record 13 of Set 1 | walvis bay
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | puerto natales
# Processing Record 16 of Set 1 | ayod
# City not found. Skipping...
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | toyooka
# Processing Record 19 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 20 of Set 1 | altamira
# Processing Record 21 of Set 1 | labrador city
# Processing Record 22 of Set 1 | gemena
# Processing Record 23 of Set 1 | nova sintra
# Processing Record 24 of Set 1 | whitehorse
# Processing Record 25 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | badger
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | papatowai
# Processing Record 30 of Set 1 | trenggalek
# Processing Record 31 of Set 1 | pecan grove
# Processing Record 32 of Set 1 | kailua-kona
# Processing Record 33 of Set 1 | monte llano
# City not found. Skipping...
# Processing Record 34 of Set 1 | constantia
# Processing Record 35 of Set 1 | tolanaro
# Processing Record 36 of Set 1 | san martin de los andes
# Processing Record 37 of Set 1 | haiku-pauwela
# Processing Record 38 of Set 1 | alice springs
# Processing Record 39 of Set 1 | adamstown
# Processing Record 40 of Set 1 | carora
# Processing Record 41 of Set 1 | pangody
# Processing Record 42 of Set 1 | zheleznodorozhnyy
# Processing Record 43 of Set 1 | chibougamau
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | college
# Processing Record 46 of Set 1 | margaret river
# Processing Record 47 of Set 1 | fale old settlement
# Processing Record 48 of Set 1 | edinburgh of the seven seas
# Processing Record 49 of Set 1 | taguatinga
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 0 of Set 2 | longyearbyen
# Processing Record 1 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 2 of Set 2 | klyuchi
# Processing Record 3 of Set 2 | hede
# Processing Record 4 of Set 2 | blackmans bay
# Processing Record 5 of Set 2 | rongelap
# Processing Record 6 of Set 2 | revda
# Processing Record 7 of Set 2 | nuku'alofa
# Processing Record 8 of Set 2 | grytviken
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | bargara
# City not found. Skipping...
# Processing Record 11 of Set 2 | maibong
# Processing Record 12 of Set 2 | kingston
# Processing Record 13 of Set 2 | lihue
# Processing Record 14 of Set 2 | tolbazy
# Processing Record 15 of Set 2 | shimanovsk
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | nouadhibou
# Processing Record 18 of Set 2 | saipan
# Processing Record 19 of Set 2 | minas de marcona
# Processing Record 20 of Set 2 | atafu village
# Processing Record 21 of Set 2 | nizhneangarsk
# Processing Record 22 of Set 2 | san antonio de pale
# Processing Record 23 of Set 2 | praya
# Processing Record 24 of Set 2 | vaskelovo
# Processing Record 25 of Set 2 | zin'kiv
# Processing Record 26 of Set 2 | douglas
# Processing Record 27 of Set 2 | port mathurin
# Processing Record 28 of Set 2 | sanming
# Processing Record 29 of Set 2 | iqaluit
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | sohagpur
# Processing Record 32 of Set 2 | talnakh
# Processing Record 33 of Set 2 | tame
# Processing Record 34 of Set 2 | aykhal
# Processing Record 35 of Set 2 | el granada
# Processing Record 36 of Set 2 | west island
# Processing Record 37 of Set 2 | wotho
# Processing Record 38 of Set 2 | linxia chengguanzhen
# Processing Record 39 of Set 2 | manokwari
# Processing Record 40 of Set 2 | portland
# Processing Record 41 of Set 2 | ormara
# Processing Record 42 of Set 2 | calabazar de sagua
# Processing Record 43 of Set 2 | utrik
# Processing Record 44 of Set 2 | anadyr
# Processing Record 45 of Set 2 | merowe
# Processing Record 46 of Set 2 | vila franca do campo
# Processing Record 47 of Set 2 | prince george
# Processing Record 48 of Set 2 | albany
# Processing Record 49 of Set 2 | nguigmi
# Processing Record 0 of Set 3 | olonkinbyen
# Processing Record 1 of Set 3 | al hoceima
# Processing Record 2 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 3 of Set 3 | invercargill
# Processing Record 4 of Set 3 | flying fish cove
# Processing Record 5 of Set 3 | bilibino
# Processing Record 6 of Set 3 | egilsstadir
# Processing Record 7 of Set 3 | nadvoitsy
# Processing Record 8 of Set 3 | jayrud
# Processing Record 9 of Set 3 | shahrak
# Processing Record 10 of Set 3 | awjilah
# Processing Record 11 of Set 3 | colonia
# Processing Record 12 of Set 3 | weno
# Processing Record 13 of Set 3 | paso de los toros
# Processing Record 14 of Set 3 | port blair
# Processing Record 15 of Set 3 | glazov
# Processing Record 16 of Set 3 | ust-nera
# Processing Record 17 of Set 3 | tura
# Processing Record 18 of Set 3 | vetluga
# Processing Record 19 of Set 3 | kondagaon
# Processing Record 20 of Set 3 | gebeit
# Processing Record 21 of Set 3 | san patricio
# Processing Record 22 of Set 3 | puerto cabello
# Processing Record 23 of Set 3 | mersing
# Processing Record 24 of Set 3 | terrace heights
# Processing Record 25 of Set 3 | amarante do maranhao
# Processing Record 26 of Set 3 | nambour
# Processing Record 27 of Set 3 | bamboo flat
# Processing Record 28 of Set 3 | belyy yar
# Processing Record 29 of Set 3 | wailua homesteads
# Processing Record 30 of Set 3 | qaqortoq
# Processing Record 31 of Set 3 | yantzaza
# Processing Record 32 of Set 3 | keflavik
# Processing Record 33 of Set 3 | howrah
# Processing Record 34 of Set 3 | anchorage
# Processing Record 35 of Set 3 | khandyga
# Processing Record 36 of Set 3 | watford city
# Processing Record 37 of Set 3 | palopo
# Processing Record 38 of Set 3 | dudinka
# Processing Record 39 of Set 3 | jamestown
# Processing Record 40 of Set 3 | motul
# Processing Record 41 of Set 3 | la jagua de ibirico
# Processing Record 42 of Set 3 | murghob
# Processing Record 43 of Set 3 | alofi
# Processing Record 44 of Set 3 | gadzhiyevo
# Processing Record 45 of Set 3 | illizi
# Processing Record 46 of Set 3 | ketchikan
# Processing Record 47 of Set 3 | rio turbio
# City not found. Skipping...
# Processing Record 48 of Set 3 | saudarkrokur
# Processing Record 49 of Set 3 | fort st. john
# Processing Record 0 of Set 4 | palmer
# Processing Record 1 of Set 4 | daura
# Processing Record 2 of Set 4 | new norfolk
# Processing Record 3 of Set 4 | fu'an
# Processing Record 4 of Set 4 | newman
# Processing Record 5 of Set 4 | port alfred
# Processing Record 6 of Set 4 | nadym
# Processing Record 7 of Set 4 | sosnogorsk
# Processing Record 8 of Set 4 | guarapari
# Processing Record 9 of Set 4 | box elder
# Processing Record 10 of Set 4 | belmonte
# Processing Record 11 of Set 4 | aasiaat
# Processing Record 12 of Set 4 | masterton
# Processing Record 13 of Set 4 | port lincoln
# Processing Record 14 of Set 4 | mahina
# Processing Record 15 of Set 4 | lerwick
# Processing Record 16 of Set 4 | santo antonio do ica
# Processing Record 17 of Set 4 | farmington
# Processing Record 18 of Set 4 | hokuto
# Processing Record 19 of Set 4 | namibe
# Processing Record 20 of Set 4 | yuzhno-kurilsk
# Processing Record 21 of Set 4 | roscommon
# Processing Record 22 of Set 4 | san juan de miraflores
# Processing Record 23 of Set 4 | acapulco de juarez
# Processing Record 24 of Set 4 | kampong chhnang
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | tomatlan
# Processing Record 27 of Set 4 | sitka
# Processing Record 28 of Set 4 | ouallam
# Processing Record 29 of Set 4 | acarau
# Processing Record 30 of Set 4 | annau
# Processing Record 31 of Set 4 | buka
# Processing Record 32 of Set 4 | nizhniy kuranakh
# Processing Record 33 of Set 4 | geraldton
# Processing Record 34 of Set 4 | belleville
# Processing Record 35 of Set 4 | sillamae
# Processing Record 36 of Set 4 | sao vicente
# Processing Record 37 of Set 4 | floro
# Processing Record 38 of Set 4 | udachny
# Processing Record 39 of Set 4 | chonchi
# Processing Record 40 of Set 4 | gagarin
# Processing Record 41 of Set 4 | fortuna
# Processing Record 42 of Set 4 | enewetak
# Processing Record 43 of Set 4 | cova figueira
# Processing Record 44 of Set 4 | yazd
# Processing Record 45 of Set 4 | karratha
# Processing Record 46 of Set 4 | challapata
# Processing Record 47 of Set 4 | general conesa
# Processing Record 48 of Set 4 | yima
# Processing Record 49 of Set 4 | magadan
# Processing Record 0 of Set 5 | madang
# Processing Record 1 of Set 5 | port moresby
# Processing Record 2 of Set 5 | shenjiamen
# Processing Record 3 of Set 5 | kuqa
# Processing Record 4 of Set 5 | biloela
# Processing Record 5 of Set 5 | hammerfest
# Processing Record 6 of Set 5 | kavalerovo
# Processing Record 7 of Set 5 | slave lake
# Processing Record 8 of Set 5 | bedi
# Processing Record 9 of Set 5 | gumel
# Processing Record 10 of Set 5 | zaozersk
# Processing Record 11 of Set 5 | encheng
# Processing Record 12 of Set 5 | nantucket
# Processing Record 13 of Set 5 | price
# Processing Record 14 of Set 5 | lodja
# Processing Record 15 of Set 5 | chuncheon
# Processing Record 16 of Set 5 | pacific grove
# Processing Record 17 of Set 5 | bima
# Processing Record 18 of Set 5 | ancud
# Processing Record 19 of Set 5 | gualaceo
# Processing Record 20 of Set 5 | isafjordur
# Processing Record 21 of Set 5 | papao
# Processing Record 22 of Set 5 | kolonia town
# Processing Record 23 of Set 5 | bom jesus
# Processing Record 24 of Set 5 | ulladulla
# Processing Record 25 of Set 5 | karungdong
# Processing Record 26 of Set 5 | kitami
# Processing Record 27 of Set 5 | punta arenas
# Processing Record 28 of Set 5 | crane
# Processing Record 29 of Set 5 | northam
# Processing Record 30 of Set 5 | penhalonga
# Processing Record 31 of Set 5 | quelimane
# Processing Record 32 of Set 5 | brookings
# Processing Record 33 of Set 5 | vilyuchinsk
# Processing Record 34 of Set 5 | dunedin
# Processing Record 35 of Set 5 | stanley
# Processing Record 36 of Set 5 | moirang
# Processing Record 37 of Set 5 | tazacorte
# Processing Record 38 of Set 5 | east london
# Processing Record 39 of Set 5 | salinopolis
# Processing Record 40 of Set 5 | tocoa
# Processing Record 41 of Set 5 | ceerigaabo
# Processing Record 42 of Set 5 | lamesa
# Processing Record 43 of Set 5 | barabinsk
# Processing Record 44 of Set 5 | la mira
# Processing Record 45 of Set 5 | ixtapa
# Processing Record 46 of Set 5 | praia da vitoria
# Processing Record 47 of Set 5 | ust-tsilma
# Processing Record 48 of Set 5 | kapchorwa
# Processing Record 49 of Set 5 | concepcion del oro
# Processing Record 0 of Set 6 | beltinci
# Processing Record 1 of Set 6 | mangrol
# Processing Record 2 of Set 6 | dalhart
# Processing Record 3 of Set 6 | brandon
# Processing Record 4 of Set 6 | north bend
# Processing Record 5 of Set 6 | vorgashor
# Processing Record 6 of Set 6 | itoman
# Processing Record 7 of Set 6 | nar'yan-mar
# Processing Record 8 of Set 6 | auki
# Processing Record 9 of Set 6 | hell-ville
# Processing Record 10 of Set 6 | loukhi
# Processing Record 11 of Set 6 | north platte
# Processing Record 12 of Set 6 | yellowknife
# Processing Record 13 of Set 6 | hamilton
# Processing Record 14 of Set 6 | tanjung pandan
# Processing Record 15 of Set 6 | fort bragg
# Processing Record 16 of Set 6 | akdagmadeni
# Processing Record 17 of Set 6 | nagqu
# Processing Record 18 of Set 6 | greymouth
# Processing Record 19 of Set 6 | pilar
# Processing Record 20 of Set 6 | rosetta
# Processing Record 21 of Set 6 | swift current
# Processing Record 22 of Set 6 | labytnangi
# Processing Record 23 of Set 6 | zuni pueblo
# Processing Record 24 of Set 6 | reggio calabria
# Processing Record 25 of Set 6 | phultala
# Processing Record 26 of Set 6 | prata
# Processing Record 27 of Set 6 | trairi
# Processing Record 28 of Set 6 | akureyri
# Processing Record 29 of Set 6 | sona
# Processing Record 30 of Set 6 | aire-sur-la-lys
# Processing Record 31 of Set 6 | murphysboro
# Processing Record 32 of Set 6 | vuktyl
# Processing Record 33 of Set 6 | ferizli
# Processing Record 34 of Set 6 | emerald
# Processing Record 35 of Set 6 | hami
# Processing Record 36 of Set 6 | lompoc
# Processing Record 37 of Set 6 | jeju city
# Processing Record 38 of Set 6 | gray
# Processing Record 39 of Set 6 | puerto el triunfo
# Processing Record 40 of Set 6 | garbahaarrey
# Processing Record 41 of Set 6 | coahuayana de hidalgo
# Processing Record 42 of Set 6 | i-n-salah
# Processing Record 43 of Set 6 | nemuro
# Processing Record 44 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 45 of Set 6 | la passe
# Processing Record 46 of Set 6 | ulety
# Processing Record 47 of Set 6 | wenatchee
# Processing Record 48 of Set 6 | buzuluk
# Processing Record 49 of Set 6 | guiuan
# Processing Record 0 of Set 7 | afaahiti
# Processing Record 1 of Set 7 | ambam
# Processing Record 2 of Set 7 | codrington
# Processing Record 3 of Set 7 | sparti
# Processing Record 4 of Set 7 | bumba
# Processing Record 5 of Set 7 | vadso
# Processing Record 6 of Set 7 | bileca
# Processing Record 7 of Set 7 | poronaysk
# Processing Record 8 of Set 7 | pattaya
# Processing Record 9 of Set 7 | yerofey pavlovich
# Processing Record 10 of Set 7 | hermanus
# Processing Record 11 of Set 7 | usinsk
# Processing Record 12 of Set 7 | taro
# Processing Record 13 of Set 7 | piotrkow trybunalski
# Processing Record 14 of Set 7 | kununurra
# Processing Record 15 of Set 7 | bikenibeu village
# Processing Record 16 of Set 7 | chernyshevskiy
# Processing Record 17 of Set 7 | sur
# Processing Record 18 of Set 7 | qalat
# Processing Record 19 of Set 7 | whyalla stuart
# City not found. Skipping...
# Processing Record 20 of Set 7 | atchison
# Processing Record 21 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 22 of Set 7 | surazh
# Processing Record 23 of Set 7 | aquin
# Processing Record 24 of Set 7 | erdenet
# Processing Record 25 of Set 7 | trevelin
# Processing Record 26 of Set 7 | happy valley-goose bay
# Processing Record 27 of Set 7 | oriximina
# Processing Record 28 of Set 7 | moranbah
# Processing Record 29 of Set 7 | farsan
# Processing Record 30 of Set 7 | san clemente
# Processing Record 31 of Set 7 | okhotsk
# Processing Record 32 of Set 7 | sisimiut
# Processing Record 33 of Set 7 | arraial do cabo
# Processing Record 34 of Set 7 | khor
# Processing Record 35 of Set 7 | saint-pierre
# Processing Record 36 of Set 7 | zhalantun
# Processing Record 37 of Set 7 | tonghae
# Processing Record 38 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 7 | al-`ula
# City not found. Skipping...
# Processing Record 40 of Set 7 | urangan
# Processing Record 41 of Set 7 | hasaki
# Processing Record 42 of Set 7 | adelaide
# Processing Record 43 of Set 7 | kish
# Processing Record 44 of Set 7 | carnarvon
# Processing Record 45 of Set 7 | voi
# Processing Record 46 of Set 7 | tsiombe
# Processing Record 47 of Set 7 | novyy urengoy
# Processing Record 48 of Set 7 | faya-largeau
# Processing Record 49 of Set 7 | bahla'
# City not found. Skipping...
# Processing Record 0 of Set 8 | halmstad
# Processing Record 1 of Set 8 | kabalo
# Processing Record 2 of Set 8 | bokhan
# Processing Record 3 of Set 8 | oudtshoorn
# Processing Record 4 of Set 8 | coquimbo
# Processing Record 5 of Set 8 | lesnikovo
# Processing Record 6 of Set 8 | bengkulu
# Processing Record 7 of Set 8 | antonio enes
# Processing Record 8 of Set 8 | selfoss
# Processing Record 9 of Set 8 | limassol
# Processing Record 10 of Set 8 | ceres
# Processing Record 11 of Set 8 | jieshi
# Processing Record 12 of Set 8 | midvagur
# Processing Record 13 of Set 8 | uturoa
# Processing Record 14 of Set 8 | cervignano del friuli
# Processing Record 15 of Set 8 | florence
# Processing Record 16 of Set 8 | zherdevka
# Processing Record 17 of Set 8 | novodvinsk
# Processing Record 18 of Set 8 | crescent city
# Processing Record 19 of Set 8 | maceio
# Processing Record 20 of Set 8 | tozkhurmato
# Processing Record 21 of Set 8 | remire-montjoly
# Processing Record 22 of Set 8 | barra de santo antonio
# Processing Record 23 of Set 8 | semey
# Processing Record 24 of Set 8 | petropavlovsk-kamchatsky
# Processing Record 25 of Set 8 | klaksvik
# Processing Record 26 of Set 8 | ngorongoro
# Processing Record 27 of Set 8 | usogorsk
# Processing Record 28 of Set 8 | volda
# Processing Record 29 of Set 8 | kalmunai
# Processing Record 30 of Set 8 | hailar
# Processing Record 31 of Set 8 | yreka
# Processing Record 32 of Set 8 | burang
# Processing Record 33 of Set 8 | g'azalkent
# Processing Record 34 of Set 8 | cockburn town
# Processing Record 35 of Set 8 | chipinge
# Processing Record 36 of Set 8 | kolonia
# Processing Record 37 of Set 8 | nikolayevsk-on-amure
# Processing Record 38 of Set 8 | beyneu
# Processing Record 39 of Set 8 | kamaishi
# Processing Record 40 of Set 8 | lautoka
# Processing Record 41 of Set 8 | damara
# Processing Record 42 of Set 8 | sandanski
# Processing Record 43 of Set 8 | broome
# Processing Record 44 of Set 8 | pangobilian
# Processing Record 45 of Set 8 | kefamenanu
# Processing Record 46 of Set 8 | crucecita
# Processing Record 47 of Set 8 | suomussalmi
# Processing Record 48 of Set 8 | duba-yurt
# Processing Record 49 of Set 8 | bonanza
# Processing Record 0 of Set 9 | machico
# Processing Record 1 of Set 9 | laboulaye
# Processing Record 2 of Set 9 | qamdo
# Processing Record 3 of Set 9 | banff
# Processing Record 4 of Set 9 | kristiansund
# Processing Record 5 of Set 9 | iskateley
# Processing Record 6 of Set 9 | prince rupert
# Processing Record 7 of Set 9 | san jose del guaviare
# Processing Record 8 of Set 9 | lobujya
# Processing Record 9 of Set 9 | mersa matruh
# Processing Record 10 of Set 9 | corner brook
# Processing Record 11 of Set 9 | vernon
# Processing Record 12 of Set 9 | berezovyy
# Processing Record 13 of Set 9 | thompson
# Processing Record 14 of Set 9 | kavarna
# Processing Record 15 of Set 9 | nema
# Processing Record 16 of Set 9 | clarence town
# Processing Record 17 of Set 9 | guia lopes da laguna
# Processing Record 18 of Set 9 | nyaunglebin
# Processing Record 19 of Set 9 | mitsamiouli
# Processing Record 20 of Set 9 | muang phonsavan
# Processing Record 21 of Set 9 | notodden
# Processing Record 22 of Set 9 | sabratah
# Processing Record 23 of Set 9 | chulym
# Processing Record 24 of Set 9 | rabo de peixe
# Processing Record 25 of Set 9 | kuala belait
# Processing Record 26 of Set 9 | el porvenir
# Processing Record 27 of Set 9 | bei'an
# Processing Record 28 of Set 9 | ploermel
# Processing Record 29 of Set 9 | kapit
# Processing Record 30 of Set 9 | altai
# Processing Record 31 of Set 9 | susuman
# Processing Record 32 of Set 9 | abong mbang
# Processing Record 33 of Set 9 | eyl
# Processing Record 34 of Set 9 | novohrad-volynskyi
# Processing Record 35 of Set 9 | prainha
# Processing Record 36 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 37 of Set 9 | mhamid
# Processing Record 38 of Set 9 | wankaner
# Processing Record 39 of Set 9 | gorgan
# Processing Record 40 of Set 9 | tadine
# Processing Record 41 of Set 9 | barhi
# Processing Record 42 of Set 9 | ocean shores
# Processing Record 43 of Set 9 | ghat
# Processing Record 44 of Set 9 | smithers
# Processing Record 45 of Set 9 | juan griego
# Processing Record 46 of Set 9 | porto novo
# Processing Record 47 of Set 9 | banda aceh
# Processing Record 48 of Set 9 | katabu
# Processing Record 49 of Set 9 | lazaro cardenas
# Processing Record 0 of Set 10 | isangel
# Processing Record 1 of Set 10 | tabou
# Processing Record 2 of Set 10 | shengli
# Processing Record 3 of Set 10 | margate
# Processing Record 4 of Set 10 | maintirano
# Processing Record 5 of Set 10 | keren
# Processing Record 6 of Set 10 | svetlyy
# Processing Record 7 of Set 10 | terra roxa
# Processing Record 8 of Set 10 | loei
# Processing Record 9 of Set 10 | mount gambier
# Processing Record 10 of Set 10 | santiago
# Processing Record 11 of Set 10 | sonsorol village
# City not found. Skipping...
# Processing Record 12 of Set 10 | guiren
# Processing Record 13 of Set 10 | luderitz
# Processing Record 14 of Set 10 | mount pearl
# Processing Record 15 of Set 10 | xai-xai
# Processing Record 16 of Set 10 | shevchenkove
# Processing Record 17 of Set 10 | suva
# Processing Record 18 of Set 10 | kenai
# Processing Record 19 of Set 10 | kataba
# Processing Record 20 of Set 10 | gualeguaychu
# Processing Record 21 of Set 10 | tanabe
# Processing Record 22 of Set 10 | bandar lampung
# Processing Record 23 of Set 10 | ranot
# Processing Record 24 of Set 10 | oranjemund
# Processing Record 25 of Set 10 | envira
# Processing Record 26 of Set 10 | yujing
# Processing Record 27 of Set 10 | pacocha
# Processing Record 28 of Set 10 | villa bruzual
# Processing Record 29 of Set 10 | anaconda
# Processing Record 30 of Set 10 | luanda
# Processing Record 31 of Set 10 | mao
# Processing Record 32 of Set 10 | igarka
# Processing Record 33 of Set 10 | cabo san lucas
# Processing Record 34 of Set 10 | aswan
# Processing Record 35 of Set 10 | loshnitsa
# Processing Record 36 of Set 10 | takamaka
# City not found. Skipping...
# Processing Record 37 of Set 10 | lorengau
# Processing Record 38 of Set 10 | namtsy
# Processing Record 39 of Set 10 | san pedro
# Processing Record 40 of Set 10 | qandala
# Processing Record 41 of Set 10 | macau
# Processing Record 42 of Set 10 | altus
# Processing Record 43 of Set 10 | kharan
# Processing Record 44 of Set 10 | conde
# Processing Record 45 of Set 10 | espargos
# City not found. Skipping...
# Processing Record 46 of Set 10 | homer
# Processing Record 47 of Set 10 | viana do castelo
# Processing Record 48 of Set 10 | pitimbu
# Processing Record 49 of Set 10 | brady
# Processing Record 0 of Set 11 | sabinas
# Processing Record 1 of Set 11 | chadron
# Processing Record 2 of Set 11 | mokhsogollokh
# Processing Record 3 of Set 11 | kargasok
# Processing Record 4 of Set 11 | sinabang
# Processing Record 5 of Set 11 | st. john's
# Processing Record 6 of Set 11 | carutapera
# Processing Record 7 of Set 11 | fandrandava
# Processing Record 8 of Set 11 | snezhinsk
# Processing Record 9 of Set 11 | ankang
# Processing Record 10 of Set 11 | sarkand
# Processing Record 11 of Set 11 | gbarnga
# Processing Record 12 of Set 11 | ryazanskaya
# Processing Record 13 of Set 11 | morehead city
# Processing Record 14 of Set 11 | bay harbor
# Processing Record 15 of Set 11 | trongsa
# Processing Record 16 of Set 11 | ad dabbah
# Processing Record 17 of Set 11 | tanout
# Processing Record 18 of Set 11 | rajanpur
# Processing Record 19 of Set 11 | ouezzane
# Processing Record 20 of Set 11 | haverhill
# Processing Record 21 of Set 11 | muroto-misakicho
# Processing Record 22 of Set 11 | humaita
# Processing Record 23 of Set 11 | kula
# Processing Record 24 of Set 11 | ziniare
# Processing Record 25 of Set 11 | porto barra do ivinheima
# Processing Record 26 of Set 11 | chalinze
# Processing Record 27 of Set 11 | iturama
# Processing Record 28 of Set 11 | villa mercedes
# Processing Record 29 of Set 11 | yanchep
# Processing Record 30 of Set 11 | ola
# Processing Record 31 of Set 11 | mulifanua
# City not found. Skipping...
# Processing Record 32 of Set 11 | kuala kangsar
# Processing Record 33 of Set 11 | kelo
# Processing Record 34 of Set 11 | al ghayzah
# Processing Record 35 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 36 of Set 11 | qal'at bishah
# City not found. Skipping...
# Processing Record 37 of Set 11 | mgandu
# Processing Record 38 of Set 11 | basco
# Processing Record 39 of Set 11 | mogocha
# Processing Record 40 of Set 11 | veinticinco de mayo
# Processing Record 41 of Set 11 | manaure
# Processing Record 42 of Set 11 | am timan
# Processing Record 43 of Set 11 | lamarque
# Processing Record 44 of Set 11 | ta`u
# Processing Record 45 of Set 11 | leppavirta
# Processing Record 46 of Set 11 | guajara mirim
# Processing Record 47 of Set 11 | mizan teferi
# Processing Record 48 of Set 11 | mejit
# Processing Record 49 of Set 11 | puerto baquerizo moreno
# Processing Record 0 of Set 12 | kabwe
# Processing Record 1 of Set 12 | arkhangel'sk
# Processing Record 2 of Set 12 | ouellah
# City not found. Skipping...
# Processing Record 3 of Set 12 | fisterra
# Processing Record 4 of Set 12 | robertsport
# Processing Record 5 of Set 12 | pilcaya
# Processing Record 6 of Set 12 | dakhla
# Processing Record 7 of Set 12 | bada
# Processing Record 8 of Set 12 | ahvaz
# Processing Record 9 of Set 12 | esquel
# Processing Record 10 of Set 12 | san andres
# Processing Record 11 of Set 12 | batouri
# Processing Record 12 of Set 12 | antofagasta
# Processing Record 13 of Set 12 | cat ba
# City not found. Skipping...
# Processing Record 14 of Set 12 | sampit
# Processing Record 15 of Set 12 | ponca city
# Processing Record 16 of Set 12 | jacmel
# Processing Record 17 of Set 12 | lazarevac
# Processing Record 18 of Set 12 | dass
# Processing Record 19 of Set 12 | tilcara
# Processing Record 20 of Set 12 | vilattikulam
# Processing Record 21 of Set 12 | moyale
# Processing Record 22 of Set 12 | kourou
# Processing Record 23 of Set 12 | shimoda
# Processing Record 24 of Set 12 | irece
# Processing Record 25 of Set 12 | susice
# Processing Record 26 of Set 12 | crotone
# Processing Record 27 of Set 12 | san antonio
# Processing Record 28 of Set 12 | vorkuta
# Processing Record 29 of Set 12 | imbituba
# Processing Record 30 of Set 12 | piti village
# Processing Record 31 of Set 12 | qurayyat
# Processing Record 32 of Set 12 | luorong
# Processing Record 33 of Set 12 | piton saint-leu
# Processing Record 34 of Set 12 | les cayes
# Processing Record 35 of Set 12 | dapa
# Processing Record 36 of Set 12 | kirensk
# Processing Record 37 of Set 12 | the dalles
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          ilulissat  69.2167  -51.1000    266.16        73          75
# 1             sabang   5.8933   95.3214    300.69        75          99
# 2             bandon  51.7469   -8.7425    273.92        89          51
# 3  port-aux-francais -49.3500   70.2167    277.13        71          15
# 4             kodiak  57.7900 -152.4072    275.88        81         100
#
#    Wind Speed Country        Date
# 0        0.00      GL  1701670075
# 1        2.07      ID  1701670075
# 2        8.86      IE  1701670076
# 3       14.75      TF  1701670076
# 4        4.12      US  1701670076

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                ilulissat  69.2167  -51.1000    266.16        73          75
# 1                   sabang   5.8933   95.3214    300.69        75          99
# 2                   bandon  51.7469   -8.7425    273.92        89          51
# 3        port-aux-francais -49.3500   70.2167    277.13        71          15
# 4                   kodiak  57.7900 -152.4072    275.88        81         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.00      GL  1701670075
# 1              2.07      ID  1701670075
# 2              8.86      IE  1701670076
# 3             14.75      TF  1701670076
# 4              4.12      US  1701670076

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], edgecolors='black')


# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2023-11-27)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2023-11-27)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2023-11-27)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plt(x_values, y_values, x_label, y_label, formula_position):
    
    (slope, y_intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    regression_points = x_values * slope + y_intercept
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regression_points, "r-", label=f'y={round(slope,2)}x + {round(y_intercept,2)}')
    
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    
    line_formula = f'y={round(slope, 2)}x + {round(y_intercept,2)}'
    plt.annotate(line_formula, xy=formula_position, xycoords='axes fraction', fontsize = 15)
    
    print(f'The r-value is: {r_value}')
    plt.show()

city_data_df.loc[city_data_df['Lat']>= 0]
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         ilulissat  69.2167  -51.1000    266.16        73          75
# 1            sabang   5.8933   95.3214    300.69        75          99
# 2            bandon  51.7469   -8.7425    273.92        89          51
# 4            kodiak  57.7900 -152.4072    275.88        81         100
# 5         kavaratti  10.5669   72.6420    302.38        72          81
# ...             ...      ...       ...       ...       ...         ...
# 559         luorong  24.4058  109.6086    290.91        65         100
# 561       les cayes  18.2000  -73.7500    296.99        75           7
# 562            dapa   9.7594  126.0531    300.58        81         100
# 563         kirensk  57.7853  108.1119    267.57        86         100
# 564      the dalles  45.5946 -121.1787    287.43        94          75
#
#          Wind Speed Country        Date
# City_ID
# 0              0.00      GL  1701670075
# 1              2.07      ID  1701670075
# 2              8.86      IE  1701670076
# 4              4.12      US  1701670076
# 5              5.16      IN  1701670076
# ...             ...     ...         ...
# 559            1.75      CN  1701670220
# 561            1.69      HT  1701670221
# 562            4.19      PH  1701670221
# 563            4.02      RU  1701670222
# 564            2.06      US  1701670222
#
# [410 rows x 9 columns]

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        ilulissat  69.2167  -51.1000    266.16        73          75
# 1           sabang   5.8933   95.3214    300.69        75          99
# 2           bandon  51.7469   -8.7425    273.92        89          51
# 4           kodiak  57.7900 -152.4072    275.88        81         100
# 5        kavaratti  10.5669   72.6420    302.38        72          81
#
#          Wind Speed Country        Date
# City_ID
# 0              0.00      GL  1701670075
# 1              2.07      ID  1701670075
# 2              8.86      IE  1701670076
# 4              4.12      US  1701670076
# 5              5.16      IN  1701670076

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']< 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3        port-aux-francais -49.3500   70.2167    277.13        71          15
# 6              broken hill -31.9500  141.4333    308.10        11           0
# 7               bredasdorp -34.5322   20.0403    292.39        54          14
# 8                 waitangi -43.9535 -176.5597    285.83        74         100
# 12              walvis bay -22.9575   14.5053    289.68        82          40
#
#          Wind Speed Country        Date
# City_ID
# 3             14.75      TF  1701670076
# 6              2.39      AU  1701670076
# 7              4.35      ZA  1701670076
# 8              0.89      NZ  1701670077
# 12             5.66     NaN  1701669811

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression_plt(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], 'Latitude', 'Max Temp', (0.05, 0.05))
# Out:
# The r-value is: -0.8784541753791668

# %%
# Linear regression on Southern Hemisphere
linear_regression_plt(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'Latitude', 'Max Temp', (0.05, 0.75))
# Out:
# The r-value is: 0.5999080769868373

# %% [markdown]
# **Discussion about the linear relationship:**
# Based on the regression analysis, it is evident that in the Northern Hemisphere, there's a marked negative correlation between temperature and latitude, indicating that temperatures drop as one moves farther from the equator. Conversely, in the Southern Hemisphere, there is a relatively strong positive correlation between maximum temperature and latitude, suggesting that maximum temperatures rise as one approaches the equator. In summary, the temperature trends in both hemispheres are inversely mirrored; in both cases, maximum temperatures decrease as distances from the equator increase.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plt(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Latitude', 'Humidity', (0.55, 0.05))
# Out:
# The r-value is: 0.38528606579785213

# %%
# Southern Hemisphere
linear_regression_plt(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Latitude', 'Humidity', (0.05, 0.05))
# Out:
# The r-value is: 0.26871041815976576

# %% [markdown]
# **Discussion about the linear relationship:** The regression analysis indicates a significant negative correlation between temperature and latitude in the Northern Hemisphere, implying that temperatures decrease as one moves further from the equator. Conversely, in the Southern Hemisphere, there is a moderately strong positive correlation, suggesting that maximum temperatures rise as one approaches the equator. Essentially, the temperature patterns in both hemispheres mirror each other inversely, with maximum temperatures dropping as locations move away from the equatorial region.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plt(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness', (0.65, 0.30))
# Out:
# The r-value is: 0.17497780944697133

# %%
# Southern Hemisphere
linear_regression_plt(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness', (0.05, 0.30))
# Out:
# The r-value is: 0.40273485785522434

# %% [markdown]
# **Discussion about the linear relationship:** cloudiness and latitude have a weak correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plt(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed', (0.05, 0.70))
# Out:
# The r-value is: 0.02365114205090867

# %%
# Southern Hemisphere
linear_regression_plt(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed', (0.05, 0.80))
# Out:
# The r-value is: -0.26709206485544307

# %% [markdown]
# **Discussion about the linear relationship:**
# Analyzing the results with the r-value, it can be concluded that there is a weak correlation between wind speed and latitude.
